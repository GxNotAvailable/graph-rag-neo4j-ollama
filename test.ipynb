# %%
from langchain_experimental.llms.ollama_functions import OllamaFunctions

llm = OllamaFunctions(model="qwen2.5", temperature=0, format="json") #可以替换成llama3

prompt = """基于以下对话历史和检索到的相关信息回答问题：

        对话历史：
        无

        当前检索到的信息：
        检索结果:
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-处理方法->检查量程的扫描末级电源电压
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-涉及的部件->扫描末级
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-原因->在个别量程，扫描末级没有电源电压
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-处理方法->测量磁控管灯丝电压,插紧灯丝插座
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-涉及的部件->磁控管灯丝
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-原因->磁控管灯丝插头接触不良，或磁控管灯丝电压数值不对
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-处理方法->用静电高压表测量发射机中高压整流器的输出电压,如果没有高压输出,则检查高压变压器、整流硅柱和滤波电容的质量
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-涉及的部件->高压整流器
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-原因->高压整流器没有高压输出
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-处理方法->在预调脉冲幅度足够大和调制管各级电压正常的条件下,如果把氛灯检电器放在调制管阳极附近氛灯应辉亮,否则更换调制管。在更换调制管后应重新对调制管老炼
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-原因->调制管衰老
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-处理方法->检查调制管各级电压,特别是帘栅压,因为帘栅压降压电阻容易烧断。
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-涉及的部件->调制管
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-原因->调制管的工作状态不对
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-处理方法->用脉冲电压表测量调制管栅极的预调脉冲幅度。如果预调脉冲幅度不够,则应检查预调器和触发脉冲形成级的工作状态和有关元件

        问题：
        荧光屏上没有回波是怎么回事

        请提供清晰简洁的答案。注意：
        1. 如果检索到了信息，请整合信息中的原话,按照类别分条回答
        2. 如果提供的信息和对话历史不足以回答问题，请直接说明"根据现有信息无法完整回答该问题"
        3. 如果问题与对话历史相关，请结合历史信息回答

        答案："""

response = llm.invoke(prompt)
print(response.content)
# Out:
# 荧光屏上没有回波可能由以下几个原因导致：
# 1. 在个别量程，扫描末级没有电源电压。需要检查量程的扫描末级电源电压。
# 2. 磁控管灯丝插头接触不良或磁控管灯丝电压数值不对。建议测量磁控管灯丝电压并插紧灯丝插座。
# 3. 高压整流器没有高压输出，需检查发射机中高压整流器的输出电压，并检查高压变压器、整流硅柱和滤波电容的质量。
# 4. 调制管衰老或工作状态不对。建议检查调制管各级电压特别是帘栅压降压电阻是否烧断；或者用脉冲电压表测量调制管栅极预调脉冲幅度，必要时检查预调器和触发脉冲形成级的工作状态。
# 如果以上步骤均未解决问题，请进一步排查其他可能的原因。

# %%
# Import the standard Ollama class instead
from langchain_community.llms import Ollama
import os

# Optional: Set environment variable if your Ollama isn't running on default localhost:11434
# os.environ["OLLAMA_BASE_URL"] = "http://your_ollama_host:port"

# Use the standard Ollama class, remove format="json"
# llm = Ollama(model="qwen2.5", temperature=0)
# If you still want to try forcing JSON output *without* the function-calling wrapper,
# you can try adding it here, but it might still cause issues.
# Better to remove it first.
llm = Ollama(model="qwen2.5", temperature=0) # Start without format="json"

# Your original prompt remains the same
prompt = """基于以下对话历史和检索到的相关信息回答问题：

        对话历史：
        无

        当前检索到的信息：
        检索结果:
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-处理方法->检查量程的扫描末级电源电压
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-涉及的部件->扫描末级
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-原因->在个别量程，扫描末级没有电源电压
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-处理方法->测量磁控管灯丝电压,插紧灯丝插座
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-涉及的部件->磁控管灯丝
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-原因->磁控管灯丝插头接触不良，或磁控管灯丝电压数值不对
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-处理方法->用静电高压表测量发射机中高压整流器的输出电压,如果没有高压输出,则检查高压变压器、整流硅柱和滤波电容的质量
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-涉及的部件->高压整流器
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-原因->高压整流器没有高压输出
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-处理方法->在预调脉冲幅度足够大和调制管各级电压正常的条件下,如果把氛灯检电器放在调制管阳极附近氛灯应辉亮,否则更换调制管。在更换调制管后应重新对调制管老炼
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-原因->调制管衰老
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-处理方法->检查调制管各级电压,特别是帘栅压,因为帘栅压降压电阻容易烧断。
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-涉及的部件->调制管
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-原因->调制管的工作状态不对
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-处理方法->用脉冲电压表测量调制管栅极的预调脉冲幅度。如果预调脉冲幅度不够,则应检查预调器和触发脉冲形成级的工作状态和有关元件

        问题：
        荧光屏上没有回波是怎么回事

        请提供清晰简洁的答案。注意：
        1. 如果检索到了信息，请整合信息中的原话,按照类别分条回答
        2. 如果提供的信息和对话历史不足以回答问题，请直接说明"根据现有信息无法完整回答该问题"
        3. 如果问题与对话历史相关，请结合历史信息回答

        答案："""

# Invoke the model
response = llm.invoke(prompt)

# Print the content (it should be a string)
print(response) # For Ollama, response is often directly the string content

# Or potentially response.content if the object structure requires it,
# but usually for the base LLM class, the response is the string itself.
# Check the type of 'response' if needed: print(type(response))
# Out:
# C:\Users\86159\AppData\Local\Temp\ipykernel_22340\2698620787.py:13: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaLLM``.
#   llm = Ollama(model="qwen2.5", temperature=0) # Start without format="json"
# 荧光屏上没有回波可能由以下原因造成，并相应的处理方法如下：
#
# 1. **扫描末级电源电压问题**：
#    - 处理方法：检查量程的扫描末级电源电压。
#
# 2. **磁控管灯丝插头接触不良或灯丝电压不对**：
#    - 处理方法：测量磁控管灯丝电压, 插紧灯丝插座。
#    - 原因：磁控管灯丝插头接触不良，或磁控管灯丝电压数值不对。
#
# 3. **高压整流器没有高压输出**：
#    - 处理方法：用静电高压表测量发射机中高压整流器的输出电压, 如果没有高压输出, 则检查高压变压器、整流硅柱和滤波电容的质量。
#    - 原因：高压整流器没有高压输出。
#
# 4. **调制管衰老或工作状态不对**：
#    - 处理方法：在预调脉冲幅度足够大和调制管各级电压正常的条件下, 如果把氛灯检电器放在调制管阳极附近氛灯应辉亮, 否则更换调制管。在更换调制管后应重新对调制管老炼。
#    - 处理方法：检查调制管各级电压, 特别是帘栅压, 因为帘栅压降压电阻容易烧断。
#    - 原因：调制管衰老或工作状态不对。
#
# 5. **预调脉冲幅度不够**：
#    - 处理方法：用脉冲电压表测量调制管栅极的预调脉冲幅度。如果预调脉冲幅度不够, 则应检查预调器和触发脉冲形成级的工作状态和有关元件。
#    - 原因：预调脉冲幅度不够。
#
# 根据上述信息，荧光屏上没有回波可能涉及扫描末级电源电压、磁控管灯丝插头接触不良或灯丝电压不对、高压整流器输出问题、调制管衰老或工作状态不对以及预调脉冲幅度不够等多种原因。

# %%
from langchain_ollama import OllamaLLM

llm = OllamaLLM(model="qwen2.5", temperature=0)

# Your original prompt remains the same
prompt = """基于以下对话历史和检索到的相关信息回答问题：

        对话历史：
        无

        当前检索到的信息：
        检索结果:
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-处理方法->检查量程的扫描末级电源电压
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-涉及的部件->扫描末级
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-原因->在个别量程，扫描末级没有电源电压
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-处理方法->测量磁控管灯丝电压,插紧灯丝插座
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-涉及的部件->磁控管灯丝
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-原因->磁控管灯丝插头接触不良，或磁控管灯丝电压数值不对
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-处理方法->用静电高压表测量发射机中高压整流器的输出电压,如果没有高压输出,则检查高压变压器、整流硅柱和滤波电容的质量
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-涉及的部件->高压整流器
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-原因->高压整流器没有高压输出
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-处理方法->在预调脉冲幅度足够大和调制管各级电压正常的条件下,如果把氛灯检电器放在调制管阳极附近氛灯应辉亮,否则更换调制管。在更换调制管后应重新对调制管老炼
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-原因->调制管衰老
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-处理方法->检查调制管各级电压,特别是帘栅压,因为帘栅压降压电阻容易烧断。
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-涉及的部件->调制管
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-原因->调制管的工作状态不对
• 荧光屏上没有回波，且没有磁控管电流，且发射机高压指示灯辉亮-处理方法->用脉冲电压表测量调制管栅极的预调脉冲幅度。如果预调脉冲幅度不够,则应检查预调器和触发脉冲形成级的工作状态和有关元件

        问题：
        荧光屏上没有回波是怎么回事

        请提供清晰简洁的答案。注意：
        1. 如果检索到了信息，请整合信息中的原话,按照类别分条回答
        2. 如果提供的信息和对话历史不足以回答问题，请直接说明"根据现有信息无法完整回答该问题"
        3. 如果问题与对话历史相关，请结合历史信息回答

        答案："""

# Invoke the model
response = llm.invoke(prompt)

# Print the content (it should be a string)
print(response) # For Ollama, response is often directly the string content

# Or potentially response.content if the object structure requires it,
# but usually for the base LLM class, the response is the string itself.
# Check the type of 'response' if needed: print(type(response))
# Out:
# 荧光屏上没有回波可能由以下原因造成，并相应的处理方法如下：
#
# 1. **扫描末级电源电压问题**：
#    - 处理方法：检查量程的扫描末级电源电压。
#
# 2. **磁控管灯丝插头接触不良或电压不对**：
#    - 处理方法：测量磁控管灯丝电压, 插紧灯丝插座。
#    - 原因：磁控管灯丝插头接触不良，或磁控管灯丝电压数值不对。
#
# 3. **高压整流器故障**：
#    - 处理方法：用静电高压表测量发射机中高压整流器的输出电压, 如果没有高压输出, 则检查高压变压器、整流硅柱和滤波电容的质量。
#    - 原因：高压整流器没有高压输出。
#
# 4. **调制管问题**：
#    - 处理方法：在预调脉冲幅度足够大和调制管各级电压正常的条件下, 如果把氛灯检电器放在调制管阳极附近氛灯应辉亮, 否则更换调制管。在更换调制管后应重新对调制管老炼。
#    - 原因：调制管衰老或工作状态不对。
#
# 5. **预调脉冲幅度不够**：
#    - 处理方法：用脉冲电压表测量调制管栅极的预调脉冲幅度。如果预调脉冲幅度不够, 则应检查预调器和触发脉冲形成级的工作状态和有关元件。
#    - 原因：调制管的工作状态不对或预调脉冲幅度不够。
#
# 根据上述信息，荧光屏上没有回波可能涉及扫描末级、磁控管灯丝、高压整流器以及调制管等多个部件的问题。需要针对具体情况进行相应的检查和处理。
